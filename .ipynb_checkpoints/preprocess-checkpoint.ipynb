# %%
import os
import pandas as pd

# %%
cwd = os.getcwd() #use __file__ if running a .py script.
file_path = os.path.join(cwd,'data','CrimesAll.csv')

# %%
file = pd.read_csv(file_path,sep=',')

# %%
file.shape
# Out:
# (7153060, 22)

# %%
file_nonulls=file.dropna(axis='index')

# %%
file_nonulls.shape
# Out:
# (6472804, 22)

# %%
file_nonulls.head()
# Out:
#              ID Case Number                    Date  \
# 63299  11665567    JC234307  04/10/2019 04:37:00 PM
# 63383  11667963    JC235212  04/12/2019 04:08:00 PM
# 63384  11667968    JC237058  04/19/2019 01:57:00 PM
# 63460  11668309    JC238187  04/25/2019 05:20:00 PM
# 63864  11692179    JC261724  05/13/2019 05:26:00 PM
#
#                                      Block  IUCR                Primary Type  \
# 63299                   102XX S VERNON AVE  1562                 SEX OFFENSE
# 63383                   032XX N KEELER AVE  1754  OFFENSE INVOLVING CHILDREN
# 63384                  002XX N LARAMIE AVE  1752  OFFENSE INVOLVING CHILDREN
# 63460  108XX S DR MARTIN LUTHER KING JR DR  0486                     BATTERY
# 63864                   090XX S RACINE AVE  0560                     ASSAULT
#
#                                              Description  \
# 63299                   AGGRAVATED CRIMINAL SEXUAL ABUSE
# 63383                     AGG SEX ASSLT OF CHILD FAM MBR
# ...

# %%
crime={
    'type': [primary_type for primary_type in file_nonulls.loc[:,'Primary Type']], 
    'latitude': [latitude for latitude in file_nonulls.loc[:,'Latitude']],
    'longitude': [longitude for longitude in file_nonulls.loc[:,'Longitude']], 
      }

# %%
pd.DataFrame(crime)
# Out:
#                                type   latitude  longitude
# 0                       SEX OFFENSE  41.708589 -87.612583
# 1        OFFENSE INVOLVING CHILDREN  41.940298 -87.732066
# 2        OFFENSE INVOLVING CHILDREN  41.884865 -87.755230
# 3                           BATTERY  41.697609 -87.613508
# 4                           ASSAULT  41.729973 -87.653167
# ...                             ...        ...        ...
# 6472799                     ASSAULT  41.959944 -87.767226
# 6472800                     BATTERY  41.917879 -87.742535
# 6472801               OTHER OFFENSE  41.862830 -87.717040
# 6472802                    HOMICIDE  41.864278 -87.659660
# 6472803                    HOMICIDE  41.864278 -87.659682
#
# [6472804 rows x 3 columns]

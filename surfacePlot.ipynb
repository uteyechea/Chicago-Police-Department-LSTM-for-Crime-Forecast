# %% [markdown]
# ### Passing x and y data to 3D Surface Plot

# %%
import plotly.graph_objects as go
import pandas as pd
import numpy as np
# Read data from a csv
z_data = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/api_docs/mt_bruno_elevation.csv')
z = z_data.values
sh_0, sh_1 = z.shape
x, y = np.linspace(0, 1, sh_0), np.linspace(0, 1, sh_1)
print(type(x),x.dtype)

fig = go.Figure(data=[go.Surface(z=z, x=x, y=y)])
fig.update_layout(title='Mt Bruno Elevation', autosize=True,
                  #width=500, height=500,
                  margin=dict(l=65, r=50, b=65, t=90))
fig.show()
# Out:
# <class 'numpy.ndarray'> float64
# <div>
#
#
#             <div id="91a9c218-79c1-497d-adf0-c54b3afcb2cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("91a9c218-79c1-497d-adf0-c54b3afcb2cf")) {
#                     Plotly.newPlot(
#                         '91a9c218-79c1-497d-adf0-c54b3afcb2cf',
# ...

# %%
z_data
# Out:
#     Unnamed: 0          0           1           2          3          4  \
# 0            0  27.809850   49.619360   83.080670  116.66320  130.41400
# 1            1  27.719660   48.550220   65.213740   95.27666  116.99640
# 2            2  30.426700   33.477520   44.809530   62.47495   77.43523
# 3            3  16.665490   30.108600   39.969520   44.12225   59.57512
# 4            4   8.815617   18.351600    8.658275   27.58590   48.62691
# 5            5   6.628881   10.413390   24.819390   26.08952   30.16050
# 6            6  21.839750    6.639270   18.970850   32.89204   43.15014
# 7            7  53.343030   26.797970    6.639270   10.88787   17.20440
# 8            8  25.667850   63.057170   22.141400   17.07400   41.74483
# 9            9  12.827000   69.205540   46.762930   13.96517   33.88744
# 10          10   0.000000   68.663960   59.043500   33.35762   47.45282
# 11          11   0.000000   95.174990   80.038180   59.89862   39.58476
# ...

# %%
sh_0
# Out:
# 25

# %%
sh_1
# Out:
# 25

# %%
data= {'first':['a','b'],'second':['c','d']}

# %%
newData=pd.DataFrame(data)

# %%
newData
# Out:
#   first second
# 0     a      c
# 1     b      d

# %%
data2=[['a','b'],['c','d']]

# %%
newData2=pd.DataFrame(data2)

# %%
newData2
# Out:
#    0  1
# 0  a  b
# 1  c  d

# %%
data=pd.read_csv('D:/MCC_tesis/crimes2.csv')
# Out:
#                ID Case Number                    Date                 Block  \
# 0        10179775    HY368117  01/01/2015 12:00:00 AM    022XX S SAWYER AVE
# 1         9993839    HY183887  01/01/2015 12:00:00 AM    068XX S PAULINA ST
# 2        10004791    HY194724  01/01/2015 12:00:00 AM   075XX S STEWART AVE
# 3        10024172    HY212630  01/01/2015 12:00:00 AM        078XX S MAY ST
# 4        10024814    HY210309  01/01/2015 12:00:00 AM   077XX S LANGLEY AVE
# ...           ...         ...                     ...                   ...
# 1048570  11548728    JB569729  12/28/2018 03:12:00 AM      044XX N BROADWAY
# 1048571  11548737    JB569737  12/28/2018 03:39:00 AM       010XX W 81ST ST
# 1048572  11548793    JB569757  12/28/2018 03:40:00 AM  074XX S PHILLIPS AVE
# 1048573  11550227    JB571352  12/28/2018 03:40:00 AM    017XX N HALSTED ST
# 1048574  11548784    JB569740  12/28/2018 03:50:00 AM  043XX W VAN BUREN ST
#
# ...

# %%
crime=pd.read_csv('C:/Users/uteye/OneDrive/Posgrado/tesis/data/crime.csv')

# %%
crime['primaryType']
# Out:
# 0                   ARSON
# 1                   ARSON
# 2                   ARSON
# 3                   ARSON
# 4                   ARSON
#               ...
# 4528    WEAPONS VIOLATION
# 4529    WEAPONS VIOLATION
# 4530    WEAPONS VIOLATION
# 4531    WEAPONS VIOLATION
# 4532    WEAPONS VIOLATION
# Name: primaryType, Length: 4533, dtype: object

# %%
import plotly.graph_objects as go
import pandas as pd
import numpy as np
# Read data from a csv
data=pd.read_csv('C:/Users/uteye/OneDrive/Posgrado/tesis/data/crime_resolution1km.csv')
#z_data = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/api_docs/mt_bruno_elevation.csv')
z = data['crimeCount']
sh_0, sh_1 = z.shape

#x= np.array(data['latitude'])
#y= np.array(data['longitude'])
#z= np.array(data['crimeCount'])
x, y = np.linspace(0, 1, sh_0), np.linspace(0, 1, sh_1)

fig = go.Figure(data=[go.Surface(z=z, x=x, y=y)])
fig.update_layout(title='All crimes - Chicago PD', autosize=True,
                  #width=500, height=500,
                  margin=dict(l=65, r=50, b=65, t=90))
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-baa0c0c73037> in <module>
#       6 #z_data = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/api_docs/mt_bruno_elevation.csv')
#       7 z = data['crimeCount']
# ----> 8 sh_0, sh_1 = z.shape
#       9
#      10 #x= np.array(data['latitude'])
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
newDAta=np.array(data['crimeCount'])

# %%
newDAta
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)
